# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("highest_earning_players.csv")

# %%
df
# Out:
#      PlayerId NameFirst   NameLast CurrentHandle CountryCode  TotalUSDPrize  \
# 0        3883     Peter  Rasmussen       dupreeh          dk     1822989.41
# 1        3679   Andreas   Højsleth         Xyp9x          dk     1799288.57
# 2        3885   Nicolai     Reedtz        dev1ce          dk     1787489.88
# 3        3672     Lukas  Rossander        gla1ve          dk     1652350.75
# 4       17800      Emil       Reif        Magisk          dk     1416448.64
# ..        ...       ...        ...           ...         ...            ...
# 995      7400     Janne   Mikkonen         Savjz          fi       50734.44
# 996      3255      Drew  Biessener   Tidesoftime          us       50449.60
# 997     49164    Simone    Liguori          Leta          it       49300.00
# 998     43043      Mike    Eichner           Ike          us       48550.00
# 999      1100   Jeffrey      Brusi          SjoW          se       47973.61
#
# ...

# %%
df.dtypes
# Out:
# PlayerId           int64
# NameFirst         object
# NameLast          object
# CurrentHandle     object
# CountryCode       object
# TotalUSDPrize    float64
# Game              object
# Genre             object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PlayerId       1000 non-null   int64
#  1   NameFirst      1000 non-null   object
#  2   NameLast       1000 non-null   object
#  3   CurrentHandle  1000 non-null   object
#  4   CountryCode    1000 non-null   object
#  5   TotalUSDPrize  1000 non-null   float64
#  6   Game           1000 non-null   object
#  7   Genre          1000 non-null   object
# dtypes: float64(1), int64(1), object(6)
# memory usage: 62.6+ KB

# %%
df.values
# Out:
# array([[3883, 'Peter', 'Rasmussen', ..., 1822989.41,
#         'Counter-Strike: Global Offensive', 'First-Person Shooter'],
#        [3679, 'Andreas', 'Højsleth', ..., 1799288.57,
#         'Counter-Strike: Global Offensive', 'First-Person Shooter'],
#        [3885, 'Nicolai', 'Reedtz', ..., 1787489.88,
#         'Counter-Strike: Global Offensive', 'First-Person Shooter'],
#        ...,
#        [49164, 'Simone', 'Liguori', ..., 49300.0, 'Hearthstone',
#         'Collectible Card Game'],
#        [43043, 'Mike', 'Eichner', ..., 48550.0, 'Hearthstone',
#         'Collectible Card Game'],
#        [1100, 'Jeffrey', 'Brusi', ..., 47973.61, 'Hearthstone',
#         'Collectible Card Game']], dtype=object)

# %%
print(df.sort_values('TotalUSDPrize', ascending=True))
# Out:
#      PlayerId   NameFirst      NameLast CurrentHandle CountryCode  \
# 899     69797           -             -           139          cn
# 898     12241     Komklit     Wongsawat        O7T-V1          th
# 897     70343           -             -          Rain          tw
# 896     83085      En Hao          Chen           Gua          tw
# 895     83084  Tseng-Yung          Chun          Kato          tw
# ..        ...         ...           ...           ...         ...
# 104     18897      Topias  Taavitsainen        Topson          fi
# 103      2811   Sébastien          Debs           Ceb          fr
# 102     30451     Anathan          Pham           ana          au
# 101      3822       Jesse      Vainikka         JerAx          fi
# 100      3304       Johan     Sundstein        N0tail          dk
#
#      TotalUSDPrize            Game                            Genre
# 899       24171.67  Arena of Valor  Multiplayer Online Battle Arena
# ...

# %%
print(df.head())
# Out:
#    PlayerId NameFirst   NameLast CurrentHandle CountryCode  TotalUSDPrize  \
# 0      3883     Peter  Rasmussen       dupreeh          dk     1822989.41
# 1      3679   Andreas   Højsleth         Xyp9x          dk     1799288.57
# 2      3885   Nicolai     Reedtz        dev1ce          dk     1787489.88
# 3      3672     Lukas  Rossander        gla1ve          dk     1652350.75
# 4     17800      Emil       Reif        Magisk          dk     1416448.64
#
#                                Game                 Genre
# 0  Counter-Strike: Global Offensive  First-Person Shooter
# 1  Counter-Strike: Global Offensive  First-Person Shooter
# 2  Counter-Strike: Global Offensive  First-Person Shooter
# 3  Counter-Strike: Global Offensive  First-Person Shooter
# 4  Counter-Strike: Global Offensive  First-Person Shooter

# %%
print(df.tail())
# Out:
#      PlayerId NameFirst   NameLast CurrentHandle CountryCode  TotalUSDPrize  \
# 995      7400     Janne   Mikkonen         Savjz          fi       50734.44
# 996      3255      Drew  Biessener   Tidesoftime          us       50449.60
# 997     49164    Simone    Liguori          Leta          it       49300.00
# 998     43043      Mike    Eichner           Ike          us       48550.00
# 999      1100   Jeffrey      Brusi          SjoW          se       47973.61
#
#             Game                  Genre
# 995  Hearthstone  Collectible Card Game
# 996  Hearthstone  Collectible Card Game
# 997  Hearthstone  Collectible Card Game
# 998  Hearthstone  Collectible Card Game
# 999  Hearthstone  Collectible Card Game

# %%
df.loc[:,'PlayerId':'CountryCode']
# Out:
#      PlayerId NameFirst   NameLast CurrentHandle CountryCode
# 0        3883     Peter  Rasmussen       dupreeh          dk
# 1        3679   Andreas   Højsleth         Xyp9x          dk
# 2        3885   Nicolai     Reedtz        dev1ce          dk
# 3        3672     Lukas  Rossander        gla1ve          dk
# 4       17800      Emil       Reif        Magisk          dk
# ..        ...       ...        ...           ...         ...
# 995      7400     Janne   Mikkonen         Savjz          fi
# 996      3255      Drew  Biessener   Tidesoftime          us
# 997     49164    Simone    Liguori          Leta          it
# 998     43043      Mike    Eichner           Ike          us
# 999      1100   Jeffrey      Brusi          SjoW          se
#
# [1000 rows x 5 columns]

# %%
df.iloc[2:5]
# Out:
#    PlayerId NameFirst   NameLast CurrentHandle CountryCode  TotalUSDPrize  \
# 2      3885   Nicolai     Reedtz        dev1ce          dk     1787489.88
# 3      3672     Lukas  Rossander        gla1ve          dk     1652350.75
# 4     17800      Emil       Reif        Magisk          dk     1416448.64
#
#                                Game                 Genre
# 2  Counter-Strike: Global Offensive  First-Person Shooter
# 3  Counter-Strike: Global Offensive  First-Person Shooter
# 4  Counter-Strike: Global Offensive  First-Person Shooter

# %%
df.describe()
# Out:
#            PlayerId  TotalUSDPrize
# count   1000.000000   1.000000e+03
# mean   27793.587000   3.977932e+05
# std    22170.225194   6.908492e+05
# min     1000.000000   2.417167e+04
# 25%     5374.500000   8.378962e+04
# 50%    23502.000000   1.683284e+05
# 75%    48127.250000   3.937352e+05
# max    83085.000000   6.952597e+06

# %%
bf = pd.read_csv("highest_earning_teams.csv")

# %%
bf
# Out:
#      TeamId               TeamName  TotalUSDPrize  TotalTournaments  \
# 0       760    San Francisco Shock      3105000.0                 7
# 1       776        London Spitfire      1591136.5                13
# 2       768     New York Excelsior      1572618.5                18
# 3       773    Philadelphia Fusion      1186278.5                15
# 4       766          Seoul Dynasty      1130000.0                 6
# ..      ...                    ...            ...               ...
# 923   24781         Rex Regum Qeon         6286.8                 2
# 924     261               Alliance         4000.0                 1
# 925     713        Marines Esports         3429.6                 1
# 926     608  British National Team         2500.0                 1
# 927     584  Swedish National Team         2500.0                 1
#
#                Game                            Genre
# 0         Overwatch             First-Person Shooter
# ...

# %%
pd.merge(df, bf, how='inner', on='TotalUSDPrize')
# Out:
#    PlayerId   NameFirst NameLast CurrentHandle CountryCode  TotalUSDPrize  \
# 0     50884  Zong Chang       Wu    BloodTrail          tw        86250.0
# 1     46854     Michael    Luker         Luker          ca        63000.0
#
#         Game_x                Genre_x  TeamId               TeamName  \
# 0  Hearthstone  Collectible Card Game     859       Guangzhou Charge
# 1  Hearthstone  Collectible Card Game     588  Finnish National Team
#
#    TotalTournaments     Game_y               Genre_y
# 0                 3  Overwatch  First-Person Shooter
# 1                 5  Overwatch  First-Person Shooter

# %%
grouped = df.groupby(by='TotalUSDPrize')

# %%
grouped

# %%
grouped = df.groupby(['PlayerId'])
grouped.sum().plot.pie(y='TotalUSDPrize', subplots=True)
# Out:
# array([<Axes: ylabel='TotalUSDPrize'>], dtype=object)
